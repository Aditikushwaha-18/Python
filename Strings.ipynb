# %%
name = "ruchi hi"
print (len(name))
print (name.endswith("hi"))
print (name.startswith("Ruc"))
print (name.startswith("ruc"))
print (name.capitalize())
# Out:
# 8
# True
# False
# True
# Ruchi hi

# %%
str = "abcd efg hij"
print (str.find("efg"))
print (str.replace("hij","klm"))
# Out:
# 5
# abcd efg klm

# %%
name = "Arpita"

c1 = name[1:4]
c2 = name[-4:-1]
c3 = name[:4]
c4 = name[2:]   #name[2:6] are similar
print (c1)
print (c2)
print (c3)
print (c4)
# Out:
# rpi
# pit
# Arpi
# pita

# %%
str = "0123456789"
c1 = str[2:7:3]

print(c1)
# Out:
# 25

# %%
a = "She is a good girl\nbut not a bad \"girl\"       "
print(a)
b = "She is a good girl\tbut not a bad girl"
print(b)
c = "She is a good girl\bbut not a bad girl"
print(c)
# Out:
# She is a good girl
# but not a bad "girl"
# She is a good girl	but not a bad girl
# She is a good girbut not a bad girl

# %% [markdown]
# Question : Write a python to display a user entered name followed by "Good Afternoon using input() function.

# %%
name = input("Enter your name here.")
print(f"Good afternoon, {name}")
# Out:
# Good afternoon, Aditi

# %% [markdown]
# Question :write a program to fill in the format given below:
#
#             Dear <|Name|>
#             You are selected!
#             <|Date|>
#             .....

# %%
name = "Aditi"
date = "21.08.25"
print (f"Dear ,{name}\nYou are selected!\n{date}\n.....") 
#can be done using replace method also.
# Out:
# Dear ,Aditi
# You are selected!
# 21.08.25
# .....

# %% [markdown]
# Question 1: Write a program to to detect double space in a string.

# %%
para = "hey! how are you. Are you fine  there?"

print(para.find("  ")) #if not found the string it gives -1
# Out:
# 30

# %% [markdown]
# Question 2: write a program to replace the double spaces from single spaces in the above        program.

# %%
para = "hey!  how are you. Are you fine  there?"
print(para.replace("  "," "))
# Out:
# hey! how are you. Are you fine there?

# %% [markdown]
# Question 3: Write a program to format the following letter using escape sequence character.
#
# Letter = "Dear Aditi, This python project is nice. Thanks!"

# %%
letter = "Dear Aditi,\n\tThis python project is nice.\nThanks!"
print(letter)
# Out:
# Dear Aditi,
# 	This python project is nice.
# Thanks!
